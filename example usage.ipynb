# %% [markdown]
# # MikeCalSetup

# %%
# Notebook setup
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## Example usage
# By creating the object mikeCalSetup.Setup, all settings, parameters and observations are extracted from the MIKE SHE file to pandas DataFrames (McKinney, 2010). Variables in the Setup class can be changed to fit the needs of the modeler. The Setup class of the mikeCalSetup python package contains a method write_files, which writes all relevant files for the calibration. In the following, an explanation of which variables can be changed for parameters and observations, before the calibration setup is written to files with the write_files method is applied.
#
# The only necessary input for the setup class is the name of the MIKE SHE file and its relative path from the current directory.

# %%
import mikecalsetup.mikecalsetup as mikecalsetup  # import mikecalsetup
mod_nme = 'Karup_basic1'  # name of model (no extension)
pth = '.\\test\\example_models\\Karup\\Karup_Basic'  # relative path to model !!! FULL PATHS NOT SUPPORTED!
setup = mikecalsetup.Setup(mod_nme, pth)

# %% [markdown]
# ### Parameters
# The values and location (line number and column in a specified file) of a number of parameters within the land use, overland flow, saturated zone, unsaturated zone and river process of MIKE SHE setup is recorded in the variable par which is a pandas dataframe.
# Note, if the MIKE SHE setup is dependent on a MIKE HYDRO (*.mhydro), vegetation proporty database (*.etv) or an unsaturated zone soil database (*.uzs) file, parameters from these files are also recorded in the dataframe automatically (not shown here).

# %%
par = setup.par
par[['value', 'line', 'col', 'file']]
# Out:
#                                                   value  line  col  \
# par_nme
# lu_LAI_FixedValue                          0.000000e+00  1511   29
# lu_C2_FixedValue                           2.000000e-01  2042   29
# lu_C3_FixedValue                           2.000000e+01  2119   29
# lu_A_ROOT_FixedValue                       2.500000e-01  2196   29
# lu_Irrigation_Gridcode1_CapacityRS         9.100000e+01  2432   31
# lu_Irrigation_Gridcode2_CapacitySIWS       9.200000e+01  2534   33
# lu_Irrigation_Gridcode3_CapacitySWS        9.300000e+01  2631   32
# lu_Irrigation_Gridcode4_CapacityES         9.400000e+01  2725   31
# lu_Demand_DemandMoistureDeficitStartConst  0.000000e+00  2779   46
# ol_DetentionStorage                        4.000000e+00  2984   22
# ol_InitialWaterDepth                       0.000000e+00  3020   22
# ol_LeakageCoeff                            0.000000e+00  3056   22
# sz_GeoUnit_1_Hest_HorConduc                1.000000e-04  4117   24
# sz_GeoUnit_1_Hest_VerConduc                1.000000e-04  4118   24
# sz_GeoUnit_1_Hest_SpecYield                2.000000e-01  4119   24
# sz_GeoUnit_1_Hest_StorageCoef              1.000000e-04  4120   26
# sz_GeoUnit_2_Hest99_HorConduc              9.900000e-04  4136   24
# sz_GeoUnit_2_Hest99_VerConduc              9.900000e-04  4137   24
# sz_GeoUnit_2_Hest99_SpecYield              1.000000e-01  4138   24
# sz_GeoUnit_2_Hest99_StorageCoef            1.000000e-04  4139   26
# sz_Drainage_TimeConstant                   5.600000e-08  5328   25
# uz_Siltloam_BYP                            2.500000e-01  3611   18
# uz_Siltloam_Thr1                           1.500000e-01  3612   19
# uz_Siltloam_Thr2                           5.000000e-02  3613   19
# uz_Loamysand_BYP                           2.500000e-01  3676   18
# uz_Loamysand_Thr1                          1.500000e-01  3677   19
# uz_Loamysand_Thr2                          5.000000e-02  3678   19
# uz_Loam_BYP                                2.500000e-01  3741   18
# uz_Loam_Thr1                               1.500000e-01  3742   19
# uz_Loam_Thr2                               5.000000e-02  3743   19
# uz_Loamysand_ReteGenuchten_ThetaS          3.900000e-01   121   21
# uz_Loamysand_HydrGenuchten_Ks              1.700000e-05   153   17
# uz_Loam_ReteGenuchten_ThetaS               4.600000e-01   285   21
# uz_Loam_HydrGenuchten_Ks                   3.700000e-06   317   17
# uz_Siltloam_ReteGenuchten_ThetaS           4.300000e-01   367   21
# uz_Siltloam_HydrGenuchten_Ks               1.900000e-06   399   17
#
#                                                                                         file
# par_nme
# lu_LAI_FixedValue                          .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_C2_FixedValue                           .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_C3_FixedValue                           .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_A_ROOT_FixedValue                       .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_Irrigation_Gridcode1_CapacityRS         .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_Irrigation_Gridcode2_CapacitySIWS       .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_Irrigation_Gridcode3_CapacitySWS        .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_Irrigation_Gridcode4_CapacityES         .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_Demand_DemandMoistureDeficitStartConst  .\test\example_models\Karup\Karup_Basic\Karup_...
# ol_DetentionStorage                        .\test\example_models\Karup\Karup_Basic\Karup_...
# ol_InitialWaterDepth                       .\test\example_models\Karup\Karup_Basic\Karup_...
# ol_LeakageCoeff                            .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_1_Hest_HorConduc                .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_1_Hest_VerConduc                .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_1_Hest_SpecYield                .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_1_Hest_StorageCoef              .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_2_Hest99_HorConduc              .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_2_Hest99_VerConduc              .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_2_Hest99_SpecYield              .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_2_Hest99_StorageCoef            .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_Drainage_TimeConstant                   .\test\example_models\Karup\Karup_Basic\Karup_...
# uz_Siltloam_BYP                            .\test\example_models\Karup\Karup_Basic\Karup_...
# uz_Siltloam_Thr1                           .\test\example_models\Karup\Karup_Basic\Karup_...
# uz_Siltloam_Thr2                           .\test\example_models\Karup\Karup_Basic\Karup_...
# uz_Loamysand_BYP                           .\test\example_models\Karup\Karup_Basic\Karup_...
# uz_Loamysand_Thr1                          .\test\example_models\Karup\Karup_Basic\Karup_...
# uz_Loamysand_Thr2                          .\test\example_models\Karup\Karup_Basic\Karup_...
# uz_Loam_BYP                                .\test\example_models\Karup\Karup_Basic\Karup_...
# uz_Loam_Thr1                               .\test\example_models\Karup\Karup_Basic\Karup_...
# uz_Loam_Thr2                               .\test\example_models\Karup\Karup_Basic\Karup_...
# uz_Loamysand_ReteGenuchten_ThetaS          test\example_models\Karup\Karup_Basic\Model in...
# uz_Loamysand_HydrGenuchten_Ks              test\example_models\Karup\Karup_Basic\Model in...
# uz_Loam_ReteGenuchten_ThetaS               test\example_models\Karup\Karup_Basic\Model in...
# uz_Loam_HydrGenuchten_Ks                   test\example_models\Karup\Karup_Basic\Model in...
# uz_Siltloam_ReteGenuchten_ThetaS           test\example_models\Karup\Karup_Basic\Model in...
# uz_Siltloam_HydrGenuchten_Ks               test\example_models\Karup\Karup_Basic\Model in...

# %% [markdown]
# A process can be excluded from parameterization by specifying the par_from variable as input to the Setup class.

# %%
setup = mikecalsetup.Setup(mod_nme, pth, par_from=['lu', 'ol', 'sz', 'river'])  # possibilites ['lu', 'ol', 'sz', 'uz', 'river']
par = setup.par
par[['value', 'line', 'col', 'file']]
# Out:
#                                                   value  line  col  \
# par_nme
# lu_LAI_FixedValue                          0.000000e+00  1511   29
# lu_C2_FixedValue                           2.000000e-01  2042   29
# lu_C3_FixedValue                           2.000000e+01  2119   29
# lu_A_ROOT_FixedValue                       2.500000e-01  2196   29
# lu_Irrigation_Gridcode1_CapacityRS         9.100000e+01  2432   31
# lu_Irrigation_Gridcode2_CapacitySIWS       9.200000e+01  2534   33
# lu_Irrigation_Gridcode3_CapacitySWS        9.300000e+01  2631   32
# lu_Irrigation_Gridcode4_CapacityES         9.400000e+01  2725   31
# lu_Demand_DemandMoistureDeficitStartConst  0.000000e+00  2779   46
# ol_DetentionStorage                        4.000000e+00  2984   22
# ol_InitialWaterDepth                       0.000000e+00  3020   22
# ol_LeakageCoeff                            0.000000e+00  3056   22
# sz_GeoUnit_1_Hest_HorConduc                1.000000e-04  4117   24
# sz_GeoUnit_1_Hest_VerConduc                1.000000e-04  4118   24
# sz_GeoUnit_1_Hest_SpecYield                2.000000e-01  4119   24
# sz_GeoUnit_1_Hest_StorageCoef              1.000000e-04  4120   26
# sz_GeoUnit_2_Hest99_HorConduc              9.900000e-04  4136   24
# sz_GeoUnit_2_Hest99_VerConduc              9.900000e-04  4137   24
# sz_GeoUnit_2_Hest99_SpecYield              1.000000e-01  4138   24
# sz_GeoUnit_2_Hest99_StorageCoef            1.000000e-04  4139   26
# sz_Drainage_TimeConstant                   5.600000e-08  5328   25
#
#                                                                                         file
# par_nme
# lu_LAI_FixedValue                          .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_C2_FixedValue                           .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_C3_FixedValue                           .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_A_ROOT_FixedValue                       .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_Irrigation_Gridcode1_CapacityRS         .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_Irrigation_Gridcode2_CapacitySIWS       .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_Irrigation_Gridcode3_CapacitySWS        .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_Irrigation_Gridcode4_CapacityES         .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_Demand_DemandMoistureDeficitStartConst  .\test\example_models\Karup\Karup_Basic\Karup_...
# ol_DetentionStorage                        .\test\example_models\Karup\Karup_Basic\Karup_...
# ol_InitialWaterDepth                       .\test\example_models\Karup\Karup_Basic\Karup_...
# ol_LeakageCoeff                            .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_1_Hest_HorConduc                .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_1_Hest_VerConduc                .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_1_Hest_SpecYield                .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_1_Hest_StorageCoef              .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_2_Hest99_HorConduc              .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_2_Hest99_VerConduc              .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_2_Hest99_SpecYield              .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_2_Hest99_StorageCoef            .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_Drainage_TimeConstant                   .\test\example_models\Karup\Karup_Basic\Karup_...

# %% [markdown]
# The concept of the class, is that all parameters and all observations specified in the setup that might be of interest, are recorded in the dataframes. It is then up to the user to exclude parameters and observations not needed for the setup.
# The parameter names are specified in the index of the pandas dataframe, and the needed parameters are therefore easily selected with the .loc function.

# %%
par = setup.par
par_nme = par.index.to_list()

# drop parameters not needed for the calibration
drop_par = ['ol_InitialWaterDepth', 'sz_Drainage_Level']
keep_par = [nme for nme in par_nme if nme not in drop_par]
par = par.loc[keep_par]
par[['value', 'line', 'col', 'file']]
# Out:
#                                                   value  line  col  \
# par_nme
# lu_LAI_FixedValue                          0.000000e+00  1511   29
# lu_C2_FixedValue                           2.000000e-01  2042   29
# lu_C3_FixedValue                           2.000000e+01  2119   29
# lu_A_ROOT_FixedValue                       2.500000e-01  2196   29
# lu_Irrigation_Gridcode1_CapacityRS         9.100000e+01  2432   31
# lu_Irrigation_Gridcode2_CapacitySIWS       9.200000e+01  2534   33
# lu_Irrigation_Gridcode3_CapacitySWS        9.300000e+01  2631   32
# lu_Irrigation_Gridcode4_CapacityES         9.400000e+01  2725   31
# lu_Demand_DemandMoistureDeficitStartConst  0.000000e+00  2779   46
# ol_DetentionStorage                        4.000000e+00  2984   22
# ol_LeakageCoeff                            0.000000e+00  3056   22
# sz_GeoUnit_1_Hest_HorConduc                1.000000e-04  4117   24
# sz_GeoUnit_1_Hest_VerConduc                1.000000e-04  4118   24
# sz_GeoUnit_1_Hest_SpecYield                2.000000e-01  4119   24
# sz_GeoUnit_1_Hest_StorageCoef              1.000000e-04  4120   26
# sz_GeoUnit_2_Hest99_HorConduc              9.900000e-04  4136   24
# sz_GeoUnit_2_Hest99_VerConduc              9.900000e-04  4137   24
# sz_GeoUnit_2_Hest99_SpecYield              1.000000e-01  4138   24
# sz_GeoUnit_2_Hest99_StorageCoef            1.000000e-04  4139   26
# sz_Drainage_TimeConstant                   5.600000e-08  5328   25
#
#                                                                                         file
# par_nme
# lu_LAI_FixedValue                          .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_C2_FixedValue                           .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_C3_FixedValue                           .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_A_ROOT_FixedValue                       .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_Irrigation_Gridcode1_CapacityRS         .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_Irrigation_Gridcode2_CapacitySIWS       .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_Irrigation_Gridcode3_CapacitySWS        .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_Irrigation_Gridcode4_CapacityES         .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_Demand_DemandMoistureDeficitStartConst  .\test\example_models\Karup\Karup_Basic\Karup_...
# ol_DetentionStorage                        .\test\example_models\Karup\Karup_Basic\Karup_...
# ol_LeakageCoeff                            .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_1_Hest_HorConduc                .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_1_Hest_VerConduc                .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_1_Hest_SpecYield                .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_1_Hest_StorageCoef              .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_2_Hest99_HorConduc              .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_2_Hest99_VerConduc              .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_2_Hest99_SpecYield              .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_2_Hest99_StorageCoef            .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_Drainage_TimeConstant                   .\test\example_models\Karup\Karup_Basic\Karup_...

# %% [markdown]
# #### Parameter naming convention
# Parameters are named by combining header names at different levels and parameter names in the input file. Further, subarea names specified in the input file are used in the parameter name. Parameters within the land use, overland flow, saturated zone, unsaturated zone and river process has the prefix lu, ol, sz, uz, riv, respectively.
# ***
# Below subsections of the Karup_basic1.she file is shown to illustrate how the parameter lu_Irrigation_Gridcode1_CapacityRS is extracted.
# (Note that in the figure the line numbers are one based and in the dataframe they are zero-based, so the same line is referenced).
#
# ![Karup1_lu_Irrigation_Gridcode1_CapacityRS-2.png](attachment:Karup1_lu_Irrigation_Gridcode1_CapacityRS-2.png)

# %%
par.loc['lu_Irrigation_Gridcode1_CapacityRS', ['value', 'line', 'col', 'file']]
# Out:
# value                                                 91.0
# line                                                  2432
# col                                                     31
# file     .\test\example_models\Karup\Karup_Basic\Karup_...
# Name: lu_Irrigation_Gridcode1_CapacityRS, dtype: object

# %% [markdown]
# #### Parameter types
# The parameters in a MIKE SHE model can be divided into two classes:
# 1. Parameters constant in time and space (within a specified zonation) that can be specified directly in the *.she, *.mhydro, *.uzs or *.etv file
# 2. Parameters that can fluctuate in time and space specified in a dfs format.
#
# The first class of parameters are recorded directly in the par dataframe. For the second class of parameters are initially recorded in the par_files dataframe.

# %%
par_files = setup.par_files
par_files
# Out:
#                                                                         file  \
# par_nme
# lu_C1_tsfile               .\test\example_models\Karup\Karup_Basic\Model_...
# lu_RD_arrfile              .\test\example_models\Karup\Karup_Basic\Model_...
# ol_Manning_arrfile         .\test\example_models\Karup\Karup_Basic\Model_...
# sz_Drainage_Level_arrfile  .\test\example_models\Karup\Karup_Basic\Level....
#
#                            item          method  \
# par_nme
# lu_C1_tsfile                  1  uniform_factor
# lu_RD_arrfile                 1  uniform_factor
# ol_Manning_arrfile            1  uniform_factor
# sz_Drainage_Level_arrfile     1  uniform_factor
#
#                                                                  value
# par_nme
# lu_C1_tsfile                               .\Model_Inputs\Time\C1.dfs0
# lu_RD_arrfile                           .\Model_Inputs\Root Depth.dfs2
# ol_Manning_arrfile         .\Model_Inputs\Maps\Manning Number (M).dfs2
# sz_Drainage_Level_arrfile                                 .\Level.dfs2

# %% [markdown]
# A few options are available for parameterization of the parameter files, which should be specified in the ‘method’ column of the par_files dataframe. These include: 1) uniform factor and 2) class value. In the uniform factor method, a parameter is created that is multiplied on the array file. In the class value method, each unique value in the original file is converted into a parameter.

# %%
# keep only part of the available parameters
keep_par = ['lu_RD_arrfile', 'ol_Manning_arrfile', 'sz_Drainage_Level_arrfile']
par_files = par_files.loc[keep_par]
# change the parameterization method for one of the parameter files
par_files.loc['lu_RD_arrfile', 'method'] = 'class_value'
# adding parameters to par
setup.par_files = par_files
setup.add_array_pars()
par[['value', 'line', 'col', 'file']]
# Out:
#                                                   value  line  col  \
# lu_LAI_FixedValue                          0.000000e+00  1511   29
# lu_C2_FixedValue                           2.000000e-01  2042   29
# lu_C3_FixedValue                           2.000000e+01  2119   29
# lu_A_ROOT_FixedValue                       2.500000e-01  2196   29
# lu_Irrigation_Gridcode1_CapacityRS         9.100000e+01  2432   31
# lu_Irrigation_Gridcode2_CapacitySIWS       9.200000e+01  2534   33
# lu_Irrigation_Gridcode3_CapacitySWS        9.300000e+01  2631   32
# lu_Irrigation_Gridcode4_CapacityES         9.400000e+01  2725   31
# lu_Demand_DemandMoistureDeficitStartConst  0.000000e+00  2779   46
# ol_DetentionStorage                        2.500000e+00  2984   22
# ol_InitialWaterDepth                       0.000000e+00  3020   22
# ol_LeakageCoeff                            0.000000e+00  3056   22
# sz_GeoUnit_1_Hest_HorConduc                1.000000e-04  4117   24
# sz_GeoUnit_1_Hest_VerConduc                1.000000e-04  4118   24
# sz_GeoUnit_1_Hest_SpecYield                2.000000e-01  4119   24
# sz_GeoUnit_1_Hest_StorageCoef              1.000000e-04  4120   26
# sz_GeoUnit_2_Hest99_HorConduc              9.900000e-04  4136   24
# sz_GeoUnit_2_Hest99_VerConduc              9.900000e-04  4137   24
# sz_GeoUnit_2_Hest99_SpecYield              1.000000e-01  4138   24
# sz_GeoUnit_2_Hest99_StorageCoef            1.000000e-04  4139   26
# sz_Drainage_TimeConstant                   5.600000e-08  5328   25
# ol_Manning_arrfile                         1.000000e+00     1  118
# sz_Drainage_Level_arrfile                  1.000000e+00     2   94
# lu_RD_arrfile00                            0.000000e+00     3   99
# extra_par                                  1.000000e+00   750   26
#
#                                                                                         file
# lu_LAI_FixedValue                          .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_C2_FixedValue                           .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_C3_FixedValue                           .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_A_ROOT_FixedValue                       .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_Irrigation_Gridcode1_CapacityRS         .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_Irrigation_Gridcode2_CapacitySIWS       .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_Irrigation_Gridcode3_CapacitySWS        .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_Irrigation_Gridcode4_CapacityES         .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_Demand_DemandMoistureDeficitStartConst  .\test\example_models\Karup\Karup_Basic\Karup_...
# ol_DetentionStorage                        .\test\example_models\Karup\Karup_Basic\Karup_...
# ol_InitialWaterDepth                       .\test\example_models\Karup\Karup_Basic\Karup_...
# ol_LeakageCoeff                            .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_1_Hest_HorConduc                .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_1_Hest_VerConduc                .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_1_Hest_SpecYield                .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_1_Hest_StorageCoef              .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_2_Hest99_HorConduc              .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_2_Hest99_VerConduc              .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_2_Hest99_SpecYield              .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_2_Hest99_StorageCoef            .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_Drainage_TimeConstant                   .\test\example_models\Karup\Karup_Basic\Karup_...
# ol_Manning_arrfile                                                     par_array_factors.txt
# sz_Drainage_Level_arrfile                                              par_array_factors.txt
# lu_RD_arrfile00                                                        par_array_factors.txt
# extra_par                                  .\test\example_models\Karup\Karup_Basic\Karup_...

# %% [markdown]
# The function setup.add_array_pars() will generate:
# - parameters that are added to the par dataframe based on the settings in the par_files dataframe.
# - an input file from where parameters are read in a model run (par_array_factors.txt).
# - a script that updates the parameters in the input file (parameter_array_update.py).
# - a template file for the distribution of class value parameters used in the above script(if class_value method is used) (*.tpl.npy)

# %% [markdown]
# #### Parameter settings
# Default calibration settings are provided for the parameters and should be changed to fit the need of the modeler. Upper and lower are set to 0.5 times the initial parameter value and 1.5 times the initial parameter value, respectively. The transform is set to 'none'.

# %%
par = setup.par
par_nme = par.index.to_list()

# set transform ['none', 'fixed', 'tied'], 
group = [nme for nme in par_nme if nme.startswith('lu_Irrigation')]
par.loc[group[0], 'transform'] = 'none'
par.loc[group[1:], 'transform'] = 'tied'
par.loc[group[1:], 'tied_to'] = group[0]

par.loc['ol_DetentionStorage', 'transform'] = 'fixed'
par.loc['ol_DetentionStorage', 'value'] = 2.5

# set upper and lower bounds
group = [nme for nme in par_nme if nme.endswith('HydrGenuchten_Ks')]
par.loc[group, ['lower', 'upper']] = 0.39, 0.46

par[['value', 'lower', 'upper', 'transform']]
# Out:
#                                                   value         lower  \
# lu_LAI_FixedValue                          0.000000e+00  0.000000e+00
# lu_C2_FixedValue                           2.000000e-01  1.000000e-01
# lu_C3_FixedValue                           2.000000e+01  1.000000e+01
# lu_A_ROOT_FixedValue                       2.500000e-01  1.250000e-01
# lu_Irrigation_Gridcode1_CapacityRS         9.100000e+01  4.550000e+01
# lu_Irrigation_Gridcode2_CapacitySIWS       9.200000e+01  4.600000e+01
# lu_Irrigation_Gridcode3_CapacitySWS        9.300000e+01  4.650000e+01
# lu_Irrigation_Gridcode4_CapacityES         9.400000e+01  4.700000e+01
# lu_Demand_DemandMoistureDeficitStartConst  0.000000e+00  0.000000e+00
# ol_DetentionStorage                        2.500000e+00  2.000000e+00
# ol_InitialWaterDepth                       0.000000e+00  0.000000e+00
# ol_LeakageCoeff                            0.000000e+00  0.000000e+00
# sz_GeoUnit_1_Hest_HorConduc                1.000000e-04  5.000000e-05
# sz_GeoUnit_1_Hest_VerConduc                1.000000e-04  5.000000e-05
# sz_GeoUnit_1_Hest_SpecYield                2.000000e-01  1.000000e-01
# sz_GeoUnit_1_Hest_StorageCoef              1.000000e-04  5.000000e-05
# sz_GeoUnit_2_Hest99_HorConduc              9.900000e-04  4.950000e-04
# sz_GeoUnit_2_Hest99_VerConduc              9.900000e-04  4.950000e-04
# sz_GeoUnit_2_Hest99_SpecYield              1.000000e-01  5.000000e-02
# sz_GeoUnit_2_Hest99_StorageCoef            1.000000e-04  5.000000e-05
# sz_Drainage_TimeConstant                   5.600000e-08  2.800000e-08
# ol_Manning_arrfile                         1.000000e+00  5.000000e-01
# sz_Drainage_Level_arrfile                  1.000000e+00  5.000000e-01
# lu_RD_arrfile00                            0.000000e+00  0.000000e+00
#
#                                                   upper transform
# lu_LAI_FixedValue                          0.000000e+00      none
# lu_C2_FixedValue                           3.000000e-01      none
# lu_C3_FixedValue                           3.000000e+01      none
# lu_A_ROOT_FixedValue                       3.750000e-01      none
# lu_Irrigation_Gridcode1_CapacityRS         1.365000e+02      none
# lu_Irrigation_Gridcode2_CapacitySIWS       1.380000e+02      tied
# lu_Irrigation_Gridcode3_CapacitySWS        1.395000e+02      tied
# lu_Irrigation_Gridcode4_CapacityES         1.410000e+02      tied
# lu_Demand_DemandMoistureDeficitStartConst  0.000000e+00      none
# ol_DetentionStorage                        6.000000e+00     fixed
# ol_InitialWaterDepth                       0.000000e+00      none
# ol_LeakageCoeff                            0.000000e+00      none
# sz_GeoUnit_1_Hest_HorConduc                1.500000e-04      none
# sz_GeoUnit_1_Hest_VerConduc                1.500000e-04      none
# sz_GeoUnit_1_Hest_SpecYield                3.000000e-01      none
# sz_GeoUnit_1_Hest_StorageCoef              1.500000e-04      none
# sz_GeoUnit_2_Hest99_HorConduc              1.485000e-03      none
# sz_GeoUnit_2_Hest99_VerConduc              1.485000e-03      none
# sz_GeoUnit_2_Hest99_SpecYield              1.500000e-01      none
# sz_GeoUnit_2_Hest99_StorageCoef            1.500000e-04      none
# sz_Drainage_TimeConstant                   8.400000e-08      none
# ol_Manning_arrfile                         1.500000e+00      none
# sz_Drainage_Level_arrfile                  1.500000e+00      none
# lu_RD_arrfile00                            0.000000e+00      none

# %% [markdown]
# #### Adding extra parameters
# Not all parameters included in the MIKE SHE input files is automatically extracted to the par dataframe. In case, the user needs additional parameters, they can be added manually to the par dataframe. The manually added parameters will be treated just like the automatically extracted parameters when added to the par dataframe. When adding the extra parameter, the values line and col must refer to a specific position in the specified file. The parameter name specified index cannot included spaces.
# Note, if changes are made to the input file, the line and col number are not automatically updated as for the automatically recorded parameters.

# %%
extra_par = {'value': 1, 'line': 750, 'col': 26, 'file':'.\\test\\example_models\\Karup\\Karup_Basic\\Karup_basic1.she',
             'lower': 0, 'upper': 2, 'transform': 'none', 'tied_factor': 1.0, 'tied_to': ''}
par.loc['extra_par'] = extra_par
par
# Out:
#                                                   value         lower  \
# lu_LAI_FixedValue                          0.000000e+00  0.000000e+00
# lu_C2_FixedValue                           2.000000e-01  1.000000e-01
# lu_C3_FixedValue                           2.000000e+01  1.000000e+01
# lu_A_ROOT_FixedValue                       2.500000e-01  1.250000e-01
# lu_Irrigation_Gridcode1_CapacityRS         9.100000e+01  4.550000e+01
# lu_Irrigation_Gridcode2_CapacitySIWS       9.200000e+01  4.600000e+01
# lu_Irrigation_Gridcode3_CapacitySWS        9.300000e+01  4.650000e+01
# lu_Irrigation_Gridcode4_CapacityES         9.400000e+01  4.700000e+01
# lu_Demand_DemandMoistureDeficitStartConst  0.000000e+00  0.000000e+00
# ol_DetentionStorage                        2.500000e+00  2.000000e+00
# ol_InitialWaterDepth                       0.000000e+00  0.000000e+00
# ol_LeakageCoeff                            0.000000e+00  0.000000e+00
# sz_GeoUnit_1_Hest_HorConduc                1.000000e-04  5.000000e-05
# sz_GeoUnit_1_Hest_VerConduc                1.000000e-04  5.000000e-05
# sz_GeoUnit_1_Hest_SpecYield                2.000000e-01  1.000000e-01
# sz_GeoUnit_1_Hest_StorageCoef              1.000000e-04  5.000000e-05
# sz_GeoUnit_2_Hest99_HorConduc              9.900000e-04  4.950000e-04
# sz_GeoUnit_2_Hest99_VerConduc              9.900000e-04  4.950000e-04
# sz_GeoUnit_2_Hest99_SpecYield              1.000000e-01  5.000000e-02
# sz_GeoUnit_2_Hest99_StorageCoef            1.000000e-04  5.000000e-05
# sz_Drainage_TimeConstant                   5.600000e-08  2.800000e-08
# ol_Manning_arrfile                         1.000000e+00  5.000000e-01
# sz_Drainage_Level_arrfile                  1.000000e+00  5.000000e-01
# lu_RD_arrfile00                            0.000000e+00  0.000000e+00
# extra_par                                  1.000000e+00  0.000000e+00
#
#                                                   upper transform  \
# lu_LAI_FixedValue                          0.000000e+00      none
# lu_C2_FixedValue                           3.000000e-01      none
# lu_C3_FixedValue                           3.000000e+01      none
# lu_A_ROOT_FixedValue                       3.750000e-01      none
# lu_Irrigation_Gridcode1_CapacityRS         1.365000e+02      none
# lu_Irrigation_Gridcode2_CapacitySIWS       1.380000e+02      tied
# lu_Irrigation_Gridcode3_CapacitySWS        1.395000e+02      tied
# lu_Irrigation_Gridcode4_CapacityES         1.410000e+02      tied
# lu_Demand_DemandMoistureDeficitStartConst  0.000000e+00      none
# ol_DetentionStorage                        6.000000e+00     fixed
# ol_InitialWaterDepth                       0.000000e+00      none
# ol_LeakageCoeff                            0.000000e+00      none
# sz_GeoUnit_1_Hest_HorConduc                1.500000e-04      none
# sz_GeoUnit_1_Hest_VerConduc                1.500000e-04      none
# sz_GeoUnit_1_Hest_SpecYield                3.000000e-01      none
# sz_GeoUnit_1_Hest_StorageCoef              1.500000e-04      none
# sz_GeoUnit_2_Hest99_HorConduc              1.485000e-03      none
# sz_GeoUnit_2_Hest99_VerConduc              1.485000e-03      none
# sz_GeoUnit_2_Hest99_SpecYield              1.500000e-01      none
# sz_GeoUnit_2_Hest99_StorageCoef            1.500000e-04      none
# sz_Drainage_TimeConstant                   8.400000e-08      none
# ol_Manning_arrfile                         1.500000e+00      none
# sz_Drainage_Level_arrfile                  1.500000e+00      none
# lu_RD_arrfile00                            0.000000e+00      none
# extra_par                                  2.000000e+00      none
#
#                                                                       tied_to  \
# lu_LAI_FixedValue
# lu_C2_FixedValue
# lu_C3_FixedValue
# lu_A_ROOT_FixedValue
# lu_Irrigation_Gridcode1_CapacityRS
# lu_Irrigation_Gridcode2_CapacitySIWS       lu_Irrigation_Gridcode1_CapacityRS
# lu_Irrigation_Gridcode3_CapacitySWS        lu_Irrigation_Gridcode1_CapacityRS
# lu_Irrigation_Gridcode4_CapacityES         lu_Irrigation_Gridcode1_CapacityRS
# lu_Demand_DemandMoistureDeficitStartConst
# ol_DetentionStorage
# ol_InitialWaterDepth
# ol_LeakageCoeff
# sz_GeoUnit_1_Hest_HorConduc
# sz_GeoUnit_1_Hest_VerConduc
# sz_GeoUnit_1_Hest_SpecYield
# sz_GeoUnit_1_Hest_StorageCoef
# sz_GeoUnit_2_Hest99_HorConduc
# sz_GeoUnit_2_Hest99_VerConduc
# sz_GeoUnit_2_Hest99_SpecYield
# sz_GeoUnit_2_Hest99_StorageCoef
# sz_Drainage_TimeConstant
# ol_Manning_arrfile
# sz_Drainage_Level_arrfile
# lu_RD_arrfile00
# extra_par
#
#                                            tied_factor  line  col  \
# lu_LAI_FixedValue                                  1.0  1511   29
# lu_C2_FixedValue                                   1.0  2042   29
# lu_C3_FixedValue                                   1.0  2119   29
# lu_A_ROOT_FixedValue                               1.0  2196   29
# lu_Irrigation_Gridcode1_CapacityRS                 1.0  2432   31
# lu_Irrigation_Gridcode2_CapacitySIWS               1.0  2534   33
# lu_Irrigation_Gridcode3_CapacitySWS                1.0  2631   32
# lu_Irrigation_Gridcode4_CapacityES                 1.0  2725   31
# lu_Demand_DemandMoistureDeficitStartConst          1.0  2779   46
# ol_DetentionStorage                                1.0  2984   22
# ol_InitialWaterDepth                               1.0  3020   22
# ol_LeakageCoeff                                    1.0  3056   22
# sz_GeoUnit_1_Hest_HorConduc                        1.0  4117   24
# sz_GeoUnit_1_Hest_VerConduc                        1.0  4118   24
# sz_GeoUnit_1_Hest_SpecYield                        1.0  4119   24
# sz_GeoUnit_1_Hest_StorageCoef                      1.0  4120   26
# sz_GeoUnit_2_Hest99_HorConduc                      1.0  4136   24
# sz_GeoUnit_2_Hest99_VerConduc                      1.0  4137   24
# sz_GeoUnit_2_Hest99_SpecYield                      1.0  4138   24
# sz_GeoUnit_2_Hest99_StorageCoef                    1.0  4139   26
# sz_Drainage_TimeConstant                           1.0  5328   25
# ol_Manning_arrfile                                 1.0     1  118
# sz_Drainage_Level_arrfile                          1.0     2   94
# lu_RD_arrfile00                                    1.0     3   99
# extra_par                                          1.0   750   26
#
#                                                                                         file
# lu_LAI_FixedValue                          .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_C2_FixedValue                           .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_C3_FixedValue                           .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_A_ROOT_FixedValue                       .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_Irrigation_Gridcode1_CapacityRS         .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_Irrigation_Gridcode2_CapacitySIWS       .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_Irrigation_Gridcode3_CapacitySWS        .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_Irrigation_Gridcode4_CapacityES         .\test\example_models\Karup\Karup_Basic\Karup_...
# lu_Demand_DemandMoistureDeficitStartConst  .\test\example_models\Karup\Karup_Basic\Karup_...
# ol_DetentionStorage                        .\test\example_models\Karup\Karup_Basic\Karup_...
# ol_InitialWaterDepth                       .\test\example_models\Karup\Karup_Basic\Karup_...
# ol_LeakageCoeff                            .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_1_Hest_HorConduc                .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_1_Hest_VerConduc                .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_1_Hest_SpecYield                .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_1_Hest_StorageCoef              .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_2_Hest99_HorConduc              .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_2_Hest99_VerConduc              .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_2_Hest99_SpecYield              .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_GeoUnit_2_Hest99_StorageCoef            .\test\example_models\Karup\Karup_Basic\Karup_...
# sz_Drainage_TimeConstant                   .\test\example_models\Karup\Karup_Basic\Karup_...
# ol_Manning_arrfile                                                     par_array_factors.txt
# sz_Drainage_Level_arrfile                                              par_array_factors.txt
# lu_RD_arrfile00                                                        par_array_factors.txt
# extra_par                                  .\test\example_models\Karup\Karup_Basic\Karup_...

# %% [markdown]
# ### Observations
# Statistics based on the observations specified in the MIKE SHE setup is automatically generated as well as a script for calculating the statistics that can be used in the calibrations setup. The observations extracted from the MIKE SHE setup is recorded to the variable results which is a pandas dataframe.
# Note, as for the parameters, observation simulation pairs can also be manually added to the results dataframe.

# %%
results = setup.results
results
# Out:
#   sim_item   name type  obs_item  \
# 0    Obs 5   Obs5    H         1
# 1   Obs 35  Obs35    H         2
# 2   Obs 37  Obs37    H         3
# 3   Obs 65  Obs65    H         4
#
#                                             sim_file  \
# 0  .\test\example_models\Karup\Karup_Basic\Karup_...
# 1  .\test\example_models\Karup\Karup_Basic\Karup_...
# 2  .\test\example_models\Karup\Karup_Basic\Karup_...
# 3  .\test\example_models\Karup\Karup_Basic\Karup_...
#
#                                             obs_file    stats
# 0  test\example_models\Karup\Karup_Basic\Model In...  kge,nse
# 1  test\example_models\Karup\Karup_Basic\Model In...  kge,nse
# 2  test\example_models\Karup\Karup_Basic\Model In...  kge,nse
# 3  test\example_models\Karup\Karup_Basic\Model In...  kge,nse

# %% [markdown]
# For each row in the results dataframe the desired statistics can be defined in the ‘stats’ column. For now the implemented statistics are root mean square error, kling gupta efficiency, nash sutcliffe, pearson correlation coefficient and flow balance. If more than one statistics is specified, they have to be seperated with a comma.

# %%
# assign needed statistics to observation-simulation pairs
results['stats'] = 'fbal, nse'  # possibilities = rmse, kge, nse, pcc, fbal delimited with comma
results
# Out:
#   sim_item   name type  obs_item  \
# 0    Obs 5   Obs5    H         1
# 1   Obs 35  Obs35    H         2
# 2   Obs 37  Obs37    H         3
# 3   Obs 65  Obs65    H         4
#
#                                             sim_file  \
# 0  .\test\example_models\Karup\Karup_Basic\Karup_...
# 1  .\test\example_models\Karup\Karup_Basic\Karup_...
# 2  .\test\example_models\Karup\Karup_Basic\Karup_...
# 3  .\test\example_models\Karup\Karup_Basic\Karup_...
#
#                                             obs_file      stats
# 0  test\example_models\Karup\Karup_Basic\Model In...  fbal, nse
# 1  test\example_models\Karup\Karup_Basic\Model In...  fbal, nse
# 2  test\example_models\Karup\Karup_Basic\Model In...  fbal, nse
# 3  test\example_models\Karup\Karup_Basic\Model In...  fbal, nse

# %% [markdown]
# In case other observations exists that cannot be specified in the MIKE SHE setup, extra scripts can be appended to the instance variable statscripts. If the statistics are appended to the ‘stats.txt’ file in the same tab separated format, these observations are also automatically included in the calibration input file.

# %%
# add extra statistics
# setup.statscripts.append('extra_stats.py')

# %% [markdown]
# ### Other important stuff
# #### Model directories and extra files
# All dependent file names are loaded into the Setup class from the *.she file. From this, the dependent directories and extra files are extracted to be used in the input file. If more directories and files are needed for running the model, directories and files can be appended to the directories instance variable list and the extra_files instance variable list, respectively.

# %%
print('Model directories:')
setup.directories
print('Model extra files:')
setup.extra_files
# Out:
# Model directories:
# ['.\\test\\example_models\\Karup\\Karup_Basic',
#  '.\\test\\example_models\\Karup\\karup_mhydro']
# Model extra files:
# []

# %% [markdown]
# #### MIKE SHE path and python environment
# The MIKE SHE path is used for running the MIKE SHE setup in the forward.bat file. A default path is specified.
# The python environment is used when running scripts in the forward.bat file.

# %%
# check that path to mike she installation is correct
setup.mzpath

# check that python environment is correct
setup.environment
# Out:
# 'C:\\Program Files (x86)\\DHI\\MIKE Zero\\2022\\bin\\x64'
# 'base'

# %% [markdown]
# ### Writing the calibration setup
# When satisfied with the setup, the files can be written using the write_files function.

# %%
# write files based on setup
setup.write_files()
# Out:
# C:\Users\wqg436\OneDrive - Københavns Universitet\packages\mikecalsetup - Copy\mikecalsetup\mikecalsetup.py:2096: UserWarning: Stat script: stats.py did not run
#   warnings.warn('Stat script: '+script+' did not run')

# %% [markdown]
# The setup.write_files() command generates:
# - template files for all specified in the file column of the parameter dataframe (*.tpl).
# - a script that will calculate model performance based on the information in results dataframe (stats.py).
# - a forward run file that will run the model once and calculate performance (forward.bat).
# - an input file to Ostrich (ostin.txt).

# %% [markdown]
# ***
# A warning is given if the stats.py script did not run. This may be because output files for MIKE SHE do not exist yet. A warning is given because the observation table in the calibration setup input file is based on the performance file stats.txt. If the stats.py file has not run, the stats.txt file is empty.

# %% [markdown]
# ### Changes to the generated calibration input file
# Configuration in the calibration input file to Ostrich can be changed with the OstFile class. With the OstFile class the generated ostin file can be loaded, the configurations can be changed and the file can be written again. For the input file to pst an option already exist in pyemu.

# %%
import mikecalsetup.ost_file as ost_file
ostin = ost_file.OstFile('./ostin.txt')
ostin.load()  # load current setup

# make changes
ostin.configbas['ProgramType'] = 'ParaPADDS'  # change to the basic configuration (section 2.3 in ostin documentation)
ostin.configbas['OstrichCaching'] = 'yes'  # change to the basic configuration (section 2.3 in ostin documentation)
ostin.configsa = ['PerturbationValue 0.2', 'MaxIterations 1000', 'SelectionMetric Random']  # change to search algorithm configuration (section 2.18-2.20 in ostin documentation)
ostin.extra_files.append('important_input_file.txt')  # add extra file

# write to same ostin file
ostin.write()

# %% [markdown]
# Further, the parameter and observation table can be directly accessed and changed through the class.

# %%
ostin.paramsdf
ostin.obsdf
# Out:
#                                              name          init           lwr  \
# 0                           __lu_LAI_FixedValue__  0.000000e+00  0.000000e+00
# 1                            __lu_C2_FixedValue__  2.000000e-01  1.000000e-01
# 2                            __lu_C3_FixedValue__  2.000000e+01  1.000000e+01
# 3                        __lu_A_ROOT_FixedValue__  2.500000e-01  1.250000e-01
# 4          __lu_Irrigation_Gridcode1_CapacityRS__  9.100000e+01  4.550000e+01
# 5   __lu_Demand_DemandMoistureDeficitStartConst__  0.000000e+00  0.000000e+00
# 6                        __ol_InitialWaterDepth__  0.000000e+00  0.000000e+00
# 7                             __ol_LeakageCoeff__  0.000000e+00  0.000000e+00
# 8                 __sz_GeoUnit_1_Hest_HorConduc__  1.000000e-04  5.000000e-05
# 9                 __sz_GeoUnit_1_Hest_VerConduc__  1.000000e-04  5.000000e-05
# 10                __sz_GeoUnit_1_Hest_SpecYield__  2.000000e-01  1.000000e-01
# 11              __sz_GeoUnit_1_Hest_StorageCoef__  1.000000e-04  5.000000e-05
# 12              __sz_GeoUnit_2_Hest99_HorConduc__  9.900000e-04  4.950000e-04
# 13              __sz_GeoUnit_2_Hest99_VerConduc__  9.900000e-04  4.950000e-04
# 14              __sz_GeoUnit_2_Hest99_SpecYield__  1.000000e-01  5.000000e-02
# 15            __sz_GeoUnit_2_Hest99_StorageCoef__  1.000000e-04  5.000000e-05
# 16                   __sz_Drainage_TimeConstant__  5.600000e-08  2.800000e-08
# 17                         __ol_Manning_arrfile__  1.000000e+00  5.000000e-01
# 18                  __sz_Drainage_Level_arrfile__  1.000000e+00  5.000000e-01
# 19                            __lu_RD_arrfile00__  0.000000e+00  0.000000e+00
#
#              upr  txIn txOst txOut    fmt
# 0   0.000000e+00  none  none  none  E10.4
# 1   3.000000e-01  none  none  none  E10.4
# 2   3.000000e+01  none  none  none  E10.4
# 3   3.750000e-01  none  none  none  E10.4
# 4   1.365000e+02  none  none  none  E10.4
# 5   0.000000e+00  none  none  none  E10.4
# 6   0.000000e+00  none  none  none  E10.4
# 7   0.000000e+00  none  none  none  E10.4
# 8   1.500000e-04  none  none  none  E10.4
# 9   1.500000e-04  none  none  none  E10.4
# 10  3.000000e-01  none  none  none  E10.4
# 11  1.500000e-04  none  none  none  E10.4
# 12  1.485000e-03  none  none  none  E10.4
# 13  1.485000e-03  none  none  none  E10.4
# 14  1.500000e-01  none  none  none  E10.4
# 15  1.500000e-04  none  none  none  E10.4
# 16  8.400000e-08  none  none  none  E10.4
# 17  1.500000e+00  none  none  none  E10.4
# 18  1.500000e+00  none  none  none  E10.4
# 19  0.000000e+00  none  none  none  E10.4
# Empty DataFrame
# Columns: [name, value, weight, file, keyword, line, col, token, aug?, group]
# Index: []
